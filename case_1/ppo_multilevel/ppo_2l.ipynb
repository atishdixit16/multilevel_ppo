# %%
# to access functions from root directory
import sys
sys.path.append('/data/ad181/RemoteDir/multilevel_ppo')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from copy import copy, deepcopy
from tqdm.notebook import trange, tqdm

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.ppo_multi_level import PPO_ML
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env.subproc_vec_multi_level_env import SubprocVecMultiLevelEnv
from stable_baselines3.common.envs.multi_level_ressim_env import MultiLevelRessimEnv
from stable_baselines3.common.logger import configure

from utils.custom_eval_callback import CustomEvalCallback, CustomEvalCallbackParallel
from utils.plot_functions import plot_learning
from utils.env_evaluate_functions import eval_actions

# %%
seed=1
case='ppo_2l'
data_dir='./data'
log_dir='./data/'+case

# %%
os.makedirs(data_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

# %%
with open('../envs_params/env_data_v1/env_train_dict.pkl', 'rb') as input:
    env_ck_dict = pickle.load(input)

# %%
# generate dictionaries for env (env_dict_), n_steps (T_ml) and minibatch (M_ml) for `n_level`s
n_levels=2
fine_level = len(env_ck_dict)
env_dict_ = {}
for i,l in enumerate(range(fine_level-n_levels, fine_level)):
    print(i+1,'->',l+1)
    env_dict_[i+1] = env_ck_dict[l+1]
# Out:
# 1 -> 4
# 2 -> 5

# %%
for seed in range(1,4):
    if True: 
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        T = {1:70, 2:5} # n_steps
        N = 50 # number of actors
        M = {1:350, 2:25} # minibatch size
        I = 300 # number of iterations
        K = 20 # number of epochs
        
        log_interval = I/30
        
        fine_level = len(env_dict_)
        
        print('generate callback ...')
        eval_callback = CustomEvalCallback( env_dict_[fine_level], 
                                            best_model_save_path=str(log_dir)+'/best_model', 
                                            n_eval_episodes=1,
                                            log_path=str(log_dir)+'/results_eval', 
                                            eval_freq=log_interval*sum(T.values()) )
        
        print('vectorize environment ...')
        
        # generate PPO_ML parameters for MLMC analysis. 
        env_dict = {}
        n_steps_dict = {}
        batch_size_dict = {}
        for env, level in zip(env_dict_.values(), env_dict_.keys()):
            print(f"vectorize env level {level}")
            env_dict[level] = make_vec_env( MultiLevelRessimEnv, 
                                    n_envs=N, 
                                    seed=seed, 
                                    env_kwargs= {"ressim_params":env.ressim_params, "level":env.level}, 
                                    vec_env_cls=SubprocVecMultiLevelEnv )
            n_steps_dict[level] = T[level]
            batch_size_dict[level] = M[level]
        
        print(env_dict_[level].observation_space)
        print('model definition ..')
        model = PPO_ML(policy=MlpPolicy,
                           env=env_dict,
                           learning_rate = 1e-5,
                           n_steps = n_steps_dict,
                           batch_size = batch_size_dict,
                           n_epochs = K,
                           clip_range = 0.1,
                           ent_coef = 0.001,
                           vf_coef = 0.5,
                           policy_kwargs = dict(net_arch=[150,100,80], log_std_init=-2.9),
                           verbose = 1,
                           seed = seed,
                           target_kl = 0.05,
                           device = "auto")
        # set logger for the model
        new_logger = configure(log_dir)
        model.set_logger(new_logger)
        print('policy learning ..')
        model.learn(total_timesteps=N*sum(T.values())*I, callback=eval_callback)
        model.save(log_dir+'/PPO', exclude=['env_dict'])
        del model
        for level in env_dict.keys():
            env_dict[level].close()
# Out:
# seed 1
# generate callback ...
# vectorize environment ...
# vectorize env level 1
# vectorize env level 2
# Box(-1.0, 1.0, (96,), float64)
# model definition ..
# Using cuda device
# Logging to ./data/ppo_2l/seed_1
# policy learning ..
# /data/ad181/RemoteDir/multilevel_ppo/utils/custom_eval_callback.py:146: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_multi_level_env.SubprocVecMultiLevelEnv object at 0x7f22cda25b90> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f22cda65150>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 0.578    |
# | time/              |          |
# |    fps             | 72       |
# |    iterations      | 1        |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3750     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.575       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 2           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 7500        |
# | train/                  |             |
# |    approx_kl            | 0.007996517 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | -4.02       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.094       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00497    |
# |    std                  | 0.055       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.579      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 3          |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 11250      |
# | train/                  |            |
# |    approx_kl            | 0.04116966 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | -0.265     |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0184     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00448   |
# |    std                  | 0.055      |
# |    value_loss           | 0.0334     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.578       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 4           |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.010356057 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0511      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000169   |
# |    std                  | 0.055       |
# |    value_loss           | 0.0227      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.582       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 5           |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 18750       |
# | train/                  |             |
# |    approx_kl            | 0.010910955 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0598      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.000801    |
# |    std                  | 0.055       |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 6           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 22500       |
# | train/                  |             |
# |    approx_kl            | 0.014879197 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0565      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00484     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.577       |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 7           |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 26250       |
# | train/                  |             |
# |    approx_kl            | 0.022980854 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0491      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00146     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 8           |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.027293028 |
# |    clip_fraction        | 0.393       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0352      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.055       |
# |    value_loss           | 0.0124      |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 9           |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 33750       |
# | train/                  |             |
# |    approx_kl            | 0.024413269 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0618      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00759     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.05
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# Eval num_timesteps=37500, episode_reward=0.59 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.594      |
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.582      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 10         |
# |    time_elapsed         | 448        |
# |    total_timesteps      | 37500      |
# | train/                  |            |
# |    approx_kl            | 0.02993982 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.627      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0305     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00417    |
# |    std                  | 0.055      |
# |    value_loss           | 0.0125     |
# ----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.584       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 11          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 41250       |
# | train/                  |             |
# |    approx_kl            | 0.030196246 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0278      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00218     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 12          |
# |    time_elapsed         | 530         |
# |    total_timesteps      | 45000       |
# | train/                  |             |
# |    approx_kl            | 0.028656159 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.072       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.055       |
# |    value_loss           | 0.00943     |
# -----------------------------------------
# Early stopping at step 19 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.581       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 13          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 48750       |
# | train/                  |             |
# |    approx_kl            | 0.023547199 |
# |    clip_fraction        | 0.487       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0271      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00327     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.586       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 14          |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 52500       |
# | train/                  |             |
# |    approx_kl            | 0.013787618 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0443      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00253    |
# |    std                  | 0.055       |
# |    value_loss           | 0.0098      |
# -----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.585       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 15          |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 56250       |
# | train/                  |             |
# |    approx_kl            | 0.032122467 |
# |    clip_fraction        | 0.474       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0286      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00798     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00868     |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.585       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 16          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.021813212 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0569      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00605     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00803     |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.585       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 17          |
# |    time_elapsed         | 736         |
# |    total_timesteps      | 63750       |
# | train/                  |             |
# |    approx_kl            | 0.017704815 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0437      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00335     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00882     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.578       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 18          |
# |    time_elapsed         | 778         |
# |    total_timesteps      | 67500       |
# | train/                  |             |
# |    approx_kl            | 0.019450666 |
# |    clip_fraction        | 0.434       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0484      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00527     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00896     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.03
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.578      |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 19         |
# |    time_elapsed         | 819        |
# |    total_timesteps      | 71250      |
# | train/                  |            |
# |    approx_kl            | 0.02039597 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.748      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0441     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0099     |
# |    std                  | 0.055      |
# |    value_loss           | 0.0088     |
# ----------------------------------------
# Early stopping at step 19 due to reaching max kl: 0.03
# Eval num_timesteps=75000, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.617       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 20          |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 75000       |
# | train/                  |             |
# |    approx_kl            | 0.024997514 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0283      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00482     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00802     |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.584       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 21          |
# |    time_elapsed         | 923         |
# |    total_timesteps      | 78750       |
# | train/                  |             |
# |    approx_kl            | 0.030460963 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0317      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00414     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00794     |
# -----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.582       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 22          |
# |    time_elapsed         | 964         |
# |    total_timesteps      | 82500       |
# | train/                  |             |
# |    approx_kl            | 0.027532514 |
# |    clip_fraction        | 0.462       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0172      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0097      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00797     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 23          |
# |    time_elapsed         | 1006        |
# |    total_timesteps      | 86250       |
# | train/                  |             |
# |    approx_kl            | 0.017770162 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0412      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00718     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00754     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 24          |
# |    time_elapsed         | 1047        |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.013585241 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0508      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00252    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00727     |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.04
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 0.589     |
# | time/                   |           |
# |    fps                  | 86        |
# |    iterations           | 25        |
# |    time_elapsed         | 1088      |
# |    total_timesteps      | 93750     |
# | train/                  |           |
# |    approx_kl            | 0.0291786 |
# |    clip_fraction        | 0.489     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -94.8     |
# |    explained_variance   | 0.798     |
# |    learning_rate        | 1e-05     |
# |    loss                 | 0.0425    |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 0.00875   |
# |    std                  | 0.055     |
# |    value_loss           | 0.00645   |
# ---------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 26          |
# |    time_elapsed         | 1129        |
# |    total_timesteps      | 97500       |
# | train/                  |             |
# |    approx_kl            | 0.026317254 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0225      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00274     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00642     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 27          |
# |    time_elapsed         | 1170        |
# |    total_timesteps      | 101250      |
# | train/                  |             |
# |    approx_kl            | 0.020415107 |
# |    clip_fraction        | 0.472       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.051       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00772     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00661     |
# -----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.08
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.59       |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 28         |
# |    time_elapsed         | 1211       |
# |    total_timesteps      | 105000     |
# | train/                  |            |
# |    approx_kl            | 0.04554894 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0528    |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.00287    |
# |    std                  | 0.055      |
# |    value_loss           | 0.0072     |
# ----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 29          |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 108750      |
# | train/                  |             |
# |    approx_kl            | 0.011710513 |
# |    clip_fraction        | 0.445       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0698      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00138    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00711     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.03
# Eval num_timesteps=112500, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.644       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 30          |
# |    time_elapsed         | 1316        |
# |    total_timesteps      | 112500      |
# | train/                  |             |
# |    approx_kl            | 0.019518219 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0266      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00671     |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 31          |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 116250      |
# | train/                  |             |
# |    approx_kl            | 0.022747094 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0461      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.055       |
# |    value_loss           | 0.0061      |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.595       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 32          |
# |    time_elapsed         | 1399        |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.017278776 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0529      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00234    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00661     |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 33          |
# |    time_elapsed         | 1440        |
# |    total_timesteps      | 123750      |
# | train/                  |             |
# |    approx_kl            | 0.019649053 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0551      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00666     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00549     |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.06
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.591       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 34          |
# |    time_elapsed         | 1480        |
# |    total_timesteps      | 127500      |
# | train/                  |             |
# |    approx_kl            | 0.034735974 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0215      |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.00814     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00523     |
# -----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 35          |
# |    time_elapsed         | 1520        |
# |    total_timesteps      | 131250      |
# | train/                  |             |
# |    approx_kl            | 0.022453934 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0375      |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00392     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00576     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.594       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 36          |
# |    time_elapsed         | 1562        |
# |    total_timesteps      | 135000      |
# | train/                  |             |
# |    approx_kl            | 0.014206834 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0635      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.000951   |
# |    std                  | 0.055       |
# |    value_loss           | 0.00643     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.595      |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 37         |
# |    time_elapsed         | 1604       |
# |    total_timesteps      | 138750     |
# | train/                  |            |
# |    approx_kl            | 0.03236131 |
# |    clip_fraction        | 0.473      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0167     |
# |    n_updates            | 720        |
# |    policy_gradient_loss | 0.00543    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00604    |
# ----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 38          |
# |    time_elapsed         | 1645        |
# |    total_timesteps      | 142500      |
# | train/                  |             |
# |    approx_kl            | 0.013166769 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.066       |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.000801    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00606     |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.597       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 39          |
# |    time_elapsed         | 1686        |
# |    total_timesteps      | 146250      |
# | train/                  |             |
# |    approx_kl            | 0.028554685 |
# |    clip_fraction        | 0.475       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0284      |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00607     |
# -----------------------------------------
# Early stopping at step 10 due to reaching max kl: 0.02
# Eval num_timesteps=150000, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.656       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 40          |
# |    time_elapsed         | 1749        |
# |    total_timesteps      | 150000      |
# | train/                  |             |
# |    approx_kl            | 0.018079296 |
# |    clip_fraction        | 0.431       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0613      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.00674     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00535     |
# -----------------------------------------
# Early stopping at step 10 due to reaching max kl: 0.10
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.597       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 41          |
# |    time_elapsed         | 1789        |
# |    total_timesteps      | 153750      |
# | train/                  |             |
# |    approx_kl            | 0.057989314 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0327     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.000511    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00545     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.598       |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 42          |
# |    time_elapsed         | 1831        |
# |    total_timesteps      | 157500      |
# | train/                  |             |
# |    approx_kl            | 0.021230929 |
# |    clip_fraction        | 0.496       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0263      |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.00398     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00513     |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.06
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.594       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 43          |
# |    time_elapsed         | 1874        |
# |    total_timesteps      | 161250      |
# | train/                  |             |
# |    approx_kl            | 0.037260134 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.000146   |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00589     |
# -----------------------------------------
# Early stopping at step 8 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.598      |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 44         |
# |    time_elapsed         | 1915       |
# |    total_timesteps      | 165000     |
# | train/                  |            |
# |    approx_kl            | 0.01353585 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0617     |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.000145  |
# |    std                  | 0.055      |
# |    value_loss           | 0.00554    |
# ----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.04
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.604      |
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 45         |
# |    time_elapsed         | 1957       |
# |    total_timesteps      | 168750     |
# | train/                  |            |
# |    approx_kl            | 0.02640482 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0282     |
# |    n_updates            | 880        |
# |    policy_gradient_loss | 0.0131     |
# |    std                  | 0.055      |
# |    value_loss           | 0.00493    |
# ----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.09
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.599       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 46          |
# |    time_elapsed         | 1999        |
# |    total_timesteps      | 172500      |
# | train/                  |             |
# |    approx_kl            | 0.049407844 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0149     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00346     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00574     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.599       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 47          |
# |    time_elapsed         | 2041        |
# |    total_timesteps      | 176250      |
# | train/                  |             |
# |    approx_kl            | 0.014688518 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0545      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00498     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00493     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 48          |
# |    time_elapsed         | 2083        |
# |    total_timesteps      | 180000      |
# | train/                  |             |
# |    approx_kl            | 0.011867981 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0663      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00194    |
# |    std                  | 0.055       |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.602       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 49          |
# |    time_elapsed         | 2124        |
# |    total_timesteps      | 183750      |
# ...
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
