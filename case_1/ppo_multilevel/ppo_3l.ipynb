# %%
# to access functions from root directory
import sys
sys.path.append('/data/ad181/RemoteDir/multilevel_ppo')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from copy import copy, deepcopy
from tqdm.notebook import trange, tqdm

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.ppo_multi_level import PPO_ML
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env.subproc_vec_multi_level_env import SubprocVecMultiLevelEnv
from stable_baselines3.common.envs.multi_level_ressim_env import MultiLevelRessimEnv
from stable_baselines3.common.logger import configure

from utils.custom_eval_callback import CustomEvalCallback, CustomEvalCallbackParallel
from utils.plot_functions import plot_learning
from utils.env_evaluate_functions import eval_actions

# %%
seed=1
case='ppo_3l'
data_dir='./data'
log_dir='./data/'+case

# %%
os.makedirs(data_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

# %%
with open('../envs_params/env_data_v1/env_train_dict.pkl', 'rb') as input:
    env_ck_dict = pickle.load(input)

# %%
# generate dictionaries for env (env_dict_), n_steps (T_ml) and minibatch (M_ml) for `n_level`s
n_levels=3
fine_level = len(env_ck_dict)
env_dict_ = {}
for i,l in enumerate(range(fine_level-n_levels, fine_level)):
    print(i+1,'->',l+1)
    env_dict_[i+1] = env_ck_dict[l+1]
# Out:
# 1 -> 3
# 2 -> 4
# 3 -> 5

# %%
for seed in range(1,4):
    if True: 
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        T = {1:80, 2:10, 3:5} # n_steps
        N = 50 # number of actors
        M = {1:400, 2:50, 3:25} # minibatch size
        I = 300 # number of iterations
        K = 20 # number of epochs
        
        log_interval = I/30
        
        fine_level = len(env_dict_)
        
        print('generate callback ...')
        eval_callback = CustomEvalCallback( env_dict_[fine_level], 
                                            best_model_save_path=str(log_dir)+'/best_model', 
                                            n_eval_episodes=1,
                                            log_path=str(log_dir)+'/results_eval', 
                                            eval_freq=log_interval*sum(T.values()) )
        
        print('vectorize environment ...')
        
        # generate PPO_ML parameters for MLMC analysis. 
        env_dict = {}
        n_steps_dict = {}
        batch_size_dict = {}
        for env, level in zip(env_dict_.values(), env_dict_.keys()):
            print(f"vectorize env level {level}")
            env_dict[level] = make_vec_env( MultiLevelRessimEnv, 
                                    n_envs=N, 
                                    seed=seed, 
                                    env_kwargs= {"ressim_params":env.ressim_params, "level":env.level}, 
                                    vec_env_cls=SubprocVecMultiLevelEnv )
            n_steps_dict[level] = T[level]
            batch_size_dict[level] = M[level]
        
        print(env_dict_[level].observation_space)
        print('model definition ..')
        model = PPO_ML(policy=MlpPolicy,
                           env=env_dict,
                           learning_rate = 1e-5,
                           n_steps = n_steps_dict,
                           batch_size = batch_size_dict,
                           n_epochs = K,
                           clip_range = 0.1,
                           ent_coef = 0.001,
                           vf_coef = 0.5,
                           policy_kwargs = dict(net_arch=[150,100,80], log_std_init=-2.9),
                           verbose = 1,
                           seed = seed,
                           target_kl = 0.05,
                           device = "auto")
        # set logger for the model
        new_logger = configure(log_dir)
        model.set_logger(new_logger)
        print('policy learning ..')
        model.learn(total_timesteps=N*sum(T.values())*I, callback=eval_callback)
        model.save(log_dir+'/PPO', exclude=['env_dict'])
        del model
        for level in env_dict.keys():
            env_dict[level].close()
# Out:
# seed 1
# generate callback ...
# vectorize environment ...
# vectorize env level 1
# vectorize env level 2
# vectorize env level 3
# Box(-1.0, 1.0, (96,), float64)
# model definition ..
# Using cuda device
# Logging to ./data/ppo_3l/seed_1
# policy learning ..
# /data/ad181/RemoteDir/multilevel_ppo/utils/custom_eval_callback.py:146: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_multi_level_env.SubprocVecMultiLevelEnv object at 0x7f1c651e9550> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f1c652173d0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 0.582    |
# | time/              |          |
# |    fps             | 81       |
# |    iterations      | 1        |
# |    time_elapsed    | 58       |
# |    total_timesteps | 4750     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.58         |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 2            |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 9500         |
# | train/                  |              |
# |    approx_kl            | 0.0064921943 |
# |    clip_fraction        | 0.313        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | -4.14        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0943       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00233     |
# |    std                  | 0.055        |
# |    value_loss           | 0.156        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 3           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 14250       |
# | train/                  |             |
# |    approx_kl            | 0.018497655 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | -0.251      |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0431      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00173     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0332      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.577       |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 4           |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 19000       |
# | train/                  |             |
# |    approx_kl            | 0.010653143 |
# |    clip_fraction        | 0.421       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0529      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00374     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0221      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 5           |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 23750       |
# | train/                  |             |
# |    approx_kl            | 0.021786707 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0451      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0152      |
# |    std                  | 0.055       |
# |    value_loss           | 0.0169      |
# -----------------------------------------
# Early stopping at step 19 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 6           |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 28500       |
# | train/                  |             |
# |    approx_kl            | 0.026253268 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0197      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00966     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.584       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 7           |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 33250       |
# | train/                  |             |
# |    approx_kl            | 0.019149706 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0421      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00637     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.581       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 8           |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 38000       |
# | train/                  |             |
# |    approx_kl            | 0.019358585 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0598      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 0.055       |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.05
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.579      |
# | time/                   |            |
# |    fps                  | 109        |
# |    iterations           | 9          |
# |    time_elapsed         | 389        |
# |    total_timesteps      | 42750      |
# | train/                  |            |
# |    approx_kl            | 0.03560801 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.658      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0443     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.017      |
# |    std                  | 0.055      |
# |    value_loss           | 0.0114     |
# ----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.07
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# Eval num_timesteps=47500, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.6         |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 10          |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 47500       |
# | train/                  |             |
# |    approx_kl            | 0.036009382 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.00366     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0092      |
# |    std                  | 0.055       |
# |    value_loss           | 0.0108      |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.583       |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 11          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 52250       |
# | train/                  |             |
# |    approx_kl            | 0.032280423 |
# |    clip_fraction        | 0.485       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0108      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00871     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 12          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 57000       |
# | train/                  |             |
# |    approx_kl            | 0.021785682 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0431      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0122      |
# |    std                  | 0.055       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# Early stopping at step 10 due to reaching max kl: 0.08
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.584      |
# | time/                   |            |
# |    fps                  | 107        |
# |    iterations           | 13         |
# |    time_elapsed         | 574        |
# |    total_timesteps      | 61750      |
# | train/                  |            |
# |    approx_kl            | 0.03520666 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.706      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0131    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.00428    |
# |    std                  | 0.055      |
# |    value_loss           | 0.0109     |
# ----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.583       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 14          |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 66500       |
# | train/                  |             |
# |    approx_kl            | 0.028826445 |
# |    clip_fraction        | 0.505       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0234      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0128      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00925     |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.585       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 15          |
# |    time_elapsed         | 653         |
# |    total_timesteps      | 71250       |
# | train/                  |             |
# |    approx_kl            | 0.014304477 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0645      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00255     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00956     |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.586       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 16          |
# |    time_elapsed         | 693         |
# |    total_timesteps      | 76000       |
# | train/                  |             |
# |    approx_kl            | 0.025623724 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.054       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0165      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00927     |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.587       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 17          |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 80750       |
# | train/                  |             |
# |    approx_kl            | 0.025304334 |
# |    clip_fraction        | 0.499       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.038       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00988     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00892     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.58        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 18          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 85500       |
# | train/                  |             |
# |    approx_kl            | 0.029473761 |
# |    clip_fraction        | 0.479       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0214      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00937     |
# |    std                  | 0.055       |
# |    value_loss           | 0.009       |
# -----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 19          |
# |    time_elapsed         | 815         |
# |    total_timesteps      | 90250       |
# | train/                  |             |
# |    approx_kl            | 0.043496788 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.00253    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0124      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00924     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.07
# Eval num_timesteps=95000, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.623       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 20          |
# |    time_elapsed         | 878         |
# |    total_timesteps      | 95000       |
# | train/                  |             |
# |    approx_kl            | 0.037440237 |
# |    clip_fraction        | 0.481       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.00742    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00877     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00796     |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.586       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 21          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 99750       |
# | train/                  |             |
# |    approx_kl            | 0.026332982 |
# |    clip_fraction        | 0.439       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.00242    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00732     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00785     |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.581       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 22          |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 104500      |
# | train/                  |             |
# |    approx_kl            | 0.021730045 |
# |    clip_fraction        | 0.484       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0379      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.014       |
# |    std                  | 0.055       |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.586       |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 23          |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 109250      |
# | train/                  |             |
# |    approx_kl            | 0.021662885 |
# |    clip_fraction        | 0.448       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0406      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00803     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00819     |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 24          |
# |    time_elapsed         | 1035        |
# |    total_timesteps      | 114000      |
# | train/                  |             |
# |    approx_kl            | 0.023007287 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0325      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0143      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00819     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 25          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 118750      |
# | train/                  |             |
# |    approx_kl            | 0.014925934 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0551      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00302     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00813     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.591       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 26          |
# |    time_elapsed         | 1116        |
# |    total_timesteps      | 123500      |
# | train/                  |             |
# |    approx_kl            | 0.021376945 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0561      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00815     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00718     |
# -----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.585      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 27         |
# |    time_elapsed         | 1155       |
# |    total_timesteps      | 128250     |
# | train/                  |            |
# |    approx_kl            | 0.01971485 |
# |    clip_fraction        | 0.45       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0444     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.00778    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00753    |
# ----------------------------------------
# Early stopping at step 5 due to reaching max kl: 0.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.591       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 28          |
# |    time_elapsed         | 1192        |
# |    total_timesteps      | 133000      |
# | train/                  |             |
# |    approx_kl            | 0.013399586 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0568      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00545     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0081      |
# -----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.08
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.588      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 29         |
# |    time_elapsed         | 1231       |
# |    total_timesteps      | 137750     |
# | train/                  |            |
# |    approx_kl            | 0.04021172 |
# |    clip_fraction        | 0.476      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.000417   |
# |    n_updates            | 560        |
# |    policy_gradient_loss | 0.00989    |
# |    std                  | 0.055      |
# |    value_loss           | 0.0069     |
# ----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.08
# Eval num_timesteps=142500, episode_reward=0.63 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.632      |
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.59       |
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 30         |
# |    time_elapsed         | 1294       |
# |    total_timesteps      | 142500     |
# | train/                  |            |
# |    approx_kl            | 0.03803683 |
# |    clip_fraction        | 0.472      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.806      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0271    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.00633    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00733    |
# ----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 31          |
# |    time_elapsed         | 1332        |
# |    total_timesteps      | 147250      |
# | train/                  |             |
# |    approx_kl            | 0.033260852 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0644     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00779     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00642     |
# -----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.594       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 32          |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 152000      |
# | train/                  |             |
# |    approx_kl            | 0.024579547 |
# |    clip_fraction        | 0.448       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0416      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00926     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0069      |
# -----------------------------------------
# Early stopping at step 9 due to reaching max kl: 0.10
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.596      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 33         |
# |    time_elapsed         | 1410       |
# |    total_timesteps      | 156750     |
# | train/                  |            |
# |    approx_kl            | 0.04676634 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.0272    |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.0118     |
# |    std                  | 0.055      |
# |    value_loss           | 0.00642    |
# ----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.06
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.594      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 34         |
# |    time_elapsed         | 1450       |
# |    total_timesteps      | 161500     |
# | train/                  |            |
# |    approx_kl            | 0.03564902 |
# |    clip_fraction        | 0.472      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 1e-05      |
# |    loss                 | -0.00901   |
# |    n_updates            | 660        |
# |    policy_gradient_loss | 0.0132     |
# |    std                  | 0.055      |
# |    value_loss           | 0.00657    |
# ----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.595       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 35          |
# |    time_elapsed         | 1488        |
# |    total_timesteps      | 166250      |
# | train/                  |             |
# |    approx_kl            | 0.023149244 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0572      |
# |    n_updates            | 680         |
# |    policy_gradient_loss | 0.00826     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00644     |
# -----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.03
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.592      |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 36         |
# |    time_elapsed         | 1528       |
# |    total_timesteps      | 171000     |
# | train/                  |            |
# |    approx_kl            | 0.02606604 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.832      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.028      |
# |    n_updates            | 700        |
# |    policy_gradient_loss | 0.016      |
# |    std                  | 0.055      |
# |    value_loss           | 0.00618    |
# ----------------------------------------
# Early stopping at step 13 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.597       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 37          |
# |    time_elapsed         | 1568        |
# |    total_timesteps      | 175750      |
# | train/                  |             |
# |    approx_kl            | 0.024962112 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0283      |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.00908     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00631     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 38          |
# |    time_elapsed         | 1607        |
# |    total_timesteps      | 180500      |
# | train/                  |             |
# |    approx_kl            | 0.018910645 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0362      |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00887     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00674     |
# -----------------------------------------
# Early stopping at step 12 due to reaching max kl: 0.02
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.594      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 39         |
# |    time_elapsed         | 1646       |
# |    total_timesteps      | 185250     |
# | train/                  |            |
# |    approx_kl            | 0.01855188 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.036      |
# |    n_updates            | 760        |
# |    policy_gradient_loss | 0.00748    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00613    |
# ----------------------------------------
# Early stopping at step 10 due to reaching max kl: 0.01
# Eval num_timesteps=190000, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.649       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.594       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 40          |
# |    time_elapsed         | 1706        |
# |    total_timesteps      | 190000      |
# | train/                  |             |
# |    approx_kl            | 0.016633622 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0443      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | 0.00967     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00621     |
# -----------------------------------------
# Early stopping at step 18 due to reaching max kl: 0.09
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.595       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 41          |
# |    time_elapsed         | 1747        |
# |    total_timesteps      | 194750      |
# | train/                  |             |
# |    approx_kl            | 0.046347838 |
# |    clip_fraction        | 0.513       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.00958     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00608     |
# -----------------------------------------
# Early stopping at step 14 due to reaching max kl: 0.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.598       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 42          |
# |    time_elapsed         | 1787        |
# |    total_timesteps      | 199500      |
# | train/                  |             |
# |    approx_kl            | 0.028769245 |
# |    clip_fraction        | 0.478       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0313      |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.0117      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00649     |
# -----------------------------------------
# Early stopping at step 16 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 43          |
# |    time_elapsed         | 1827        |
# |    total_timesteps      | 204250      |
# | train/                  |             |
# |    approx_kl            | 0.022840917 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0181      |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.00662     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00592     |
# -----------------------------------------
# Early stopping at step 17 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.601       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 44          |
# |    time_elapsed         | 1867        |
# |    total_timesteps      | 209000      |
# | train/                  |             |
# |    approx_kl            | 0.024037356 |
# |    clip_fraction        | 0.486       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0464      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.0096      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00588     |
# -----------------------------------------
# Early stopping at step 19 due to reaching max kl: 0.03
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.599       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 45          |
# |    time_elapsed         | 1908        |
# |    total_timesteps      | 213750      |
# | train/                  |             |
# |    approx_kl            | 0.021497095 |
# |    clip_fraction        | 0.49        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0666      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.0102      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00554     |
# -----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 46          |
# |    time_elapsed         | 1948        |
# |    total_timesteps      | 218500      |
# | train/                  |             |
# |    approx_kl            | 0.022165732 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0431      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00653     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00526     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.02
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.602       |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 47          |
# |    time_elapsed         | 1988        |
# |    total_timesteps      | 223250      |
# | train/                  |             |
# |    approx_kl            | 0.018692145 |
# |    clip_fraction        | 0.462       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0212      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00505     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00548     |
# -----------------------------------------
# Early stopping at step 15 due to reaching max kl: 0.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 48          |
# |    time_elapsed         | 2028        |
# |    total_timesteps      | 228000      |
# | train/                  |             |
# |    approx_kl            | 0.041690897 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.0148     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.00823     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00523     |
# -----------------------------------------
# Early stopping at step 11 due to reaching max kl: 0.10
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.602      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 49         |
# ...
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:51: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
