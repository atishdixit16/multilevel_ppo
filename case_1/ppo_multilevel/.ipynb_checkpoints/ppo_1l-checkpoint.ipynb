# %%
# to access functions from root directory
import sys
sys.path.append('/data/ad181/RemoteDir/multilevel_ppo')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from copy import copy, deepcopy
from tqdm.notebook import trange, tqdm

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.ppo_multi_level import PPO_ML
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env.subproc_vec_multi_level_env import SubprocVecMultiLevelEnv
from stable_baselines3.common.envs.multi_level_ressim_env import MultiLevelRessimEnv
from stable_baselines3.common.logger import configure

from utils.custom_eval_callback import CustomEvalCallback, CustomEvalCallbackParallel
from utils.plot_functions import plot_learning
from utils.env_evaluate_functions import eval_actions

# %%
seed=1
case='ppo_1l'
data_dir='./data'
log_dir='./data/'+case

# %%
os.makedirs(data_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

# %%
with open('../envs_params/env_data_v1/env_train_dict.pkl', 'rb') as input:
    env_ck_dict = pickle.load(input)

# %%
# generate dictionaries for env (env_dict_), n_steps (T_ml) and minibatch (M_ml) for `n_level`s
n_levels=1
fine_level = len(env_ck_dict)
env_dict_ = {}
for i,l in enumerate(range(fine_level-n_levels, fine_level)):
    print(i+1,'->',l+1)
    env_dict_[i+1] = env_ck_dict[l+1]
# Out:
# 1 -> 5

# %%
for seed in range(1,4):
    if True: 
        print(f'seed {seed}')
        log_dir = './data/'+case+'/seed_'+str(seed)
        os.makedirs(log_dir, exist_ok=True)
        T = 50 # n_steps
        N = 50 # number of actors
        M = 250 # minibatch size
        I = 300 # number of iterations
        K = 20 # number of epochs
        
        log_interval = I/30
        
        fine_level = len(env_dict_)
        
        print('generate callback ...')
        eval_callback = CustomEvalCallback( env_dict_[fine_level], 
                                            best_model_save_path=None, 
                                            n_eval_episodes=1,
                                            log_path=str(log_dir)+'/results_eval', 
                                            eval_freq=log_interval*T)
        
        print('vectorize environment ...')
        
        # generate PPO_ML parameters for MLMC analysis. 
        # we choose same n_steps and batch_size values on levels because only fine level values are used in the analysis
        env_dict = {}
        n_steps_dict = {}
        batch_size_dict = {}
        for env, level in zip(env_dict_.values(), env_dict_.keys()):
            print(f"vectorize env level {level}")
            env_dict[level] = make_vec_env( MultiLevelRessimEnv, 
                                    n_envs=N, 
                                    seed=seed, 
                                    env_kwargs= {"ressim_params":env.ressim_params, "level":env.level}, 
                                    vec_env_cls=SubprocVecMultiLevelEnv )
            n_steps_dict[level] = T
            batch_size_dict[level] = M
        
        print(env_dict_[level].observation_space)
        print('model definition ..')
        model = PPO_ML(policy=MlpPolicy,
                           env=env_dict,
                           learning_rate = 1e-5,
                           n_steps = n_steps_dict,
                           batch_size = batch_size_dict,
                           n_epochs = K,
                           clip_range = 0.1,
                           ent_coef = 0.001,
                           vf_coef = 0.5,
                           policy_kwargs = dict(net_arch=[150,100,80], log_std_init=-2.9),
                           verbose = 1,
                           seed = seed,
                           target_kl = 0.05,
                           device = "auto")
        # set logger for the model
        new_logger = configure(log_dir)
        model.set_logger(new_logger)
        print('policy learning ..')
        model.learn(total_timesteps=N*T*I, callback=eval_callback)
        model.save(log_dir+'/PPO', exclude=['env_dict'])
        del model
        for level in env_dict.keys():
            env_dict[level].close()
# Out:
# seed 1
# generate callback ...
# vectorize environment ...
# vectorize env level 1
# Box(-1.0, 1.0, (96,), float64)
# model definition ..
# Using cuda device
# Logging to ./data/case_1_mlmc_ppo_1_level/seed_1
# policy learning ..
# /data/ad181/RemoteDir/multilevel_ppo/utils/custom_eval_callback.py:146: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_multi_level_env.SubprocVecMultiLevelEnv object at 0x7fa1efe0d0d0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fa1efdf4e10>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 0.576    |
# | time/              |          |
# |    fps             | 11       |
# |    iterations      | 1        |
# |    time_elapsed    | 225      |
# |    total_timesteps | 2500     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.578       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 2           |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.006550616 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | -3.95       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.105       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.055       |
# |    value_loss           | 0.143       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.578        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 3            |
# |    time_elapsed         | 670          |
# |    total_timesteps      | 7500         |
# | train/                  |              |
# |    approx_kl            | 0.0065990128 |
# |    clip_fraction        | 0.366        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | -0.422       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.059        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0339      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0354       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.582        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 4            |
# |    time_elapsed         | 892          |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0067763682 |
# |    clip_fraction        | 0.344        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0616       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0326      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0223       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.58         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 5            |
# |    time_elapsed         | 1115         |
# |    total_timesteps      | 12500        |
# | train/                  |              |
# |    approx_kl            | 0.0075703324 |
# |    clip_fraction        | 0.382        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0552       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.036       |
# |    std                  | 0.055        |
# |    value_loss           | 0.0172       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.578        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 6            |
# |    time_elapsed         | 1340         |
# |    total_timesteps      | 15000        |
# | train/                  |              |
# |    approx_kl            | 0.0080720885 |
# |    clip_fraction        | 0.37         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0618       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0345      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0148       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.577       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 7           |
# |    time_elapsed         | 1564        |
# |    total_timesteps      | 17500       |
# | train/                  |             |
# |    approx_kl            | 0.007506261 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0526      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0343     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0144      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.581       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.007848279 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.053       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0356     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.578        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 9            |
# |    time_elapsed         | 2009         |
# |    total_timesteps      | 22500        |
# | train/                  |              |
# |    approx_kl            | 0.0072850157 |
# |    clip_fraction        | 0.366        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0572       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0342      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0115       |
# ------------------------------------------
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# Eval num_timesteps=25000, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.608       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.581       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 10          |
# |    time_elapsed         | 2259        |
# |    total_timesteps      | 25000       |
# | train/                  |             |
# |    approx_kl            | 0.007449447 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0577      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0339     |
# |    std                  | 0.055       |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.583       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 11          |
# |    time_elapsed         | 2482        |
# |    total_timesteps      | 27500       |
# | train/                  |             |
# |    approx_kl            | 0.008832766 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0533      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00994     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.584       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 12          |
# |    time_elapsed         | 2706        |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.005578634 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0514      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0093      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.581        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 13           |
# |    time_elapsed         | 2933         |
# |    total_timesteps      | 32500        |
# | train/                  |              |
# |    approx_kl            | 0.0074409614 |
# |    clip_fraction        | 0.367        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0513       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0344      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0093       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.583      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 14         |
# |    time_elapsed         | 3158       |
# |    total_timesteps      | 35000      |
# | train/                  |            |
# |    approx_kl            | 0.00748061 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0467     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0362    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00901    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.586       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 15          |
# |    time_elapsed         | 3382        |
# |    total_timesteps      | 37500       |
# | train/                  |             |
# |    approx_kl            | 0.008839962 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0476      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0363     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00835     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.59        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 16          |
# |    time_elapsed         | 3603        |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.007828413 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0459      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00829     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.587       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 17          |
# |    time_elapsed         | 3828        |
# |    total_timesteps      | 42500       |
# | train/                  |             |
# |    approx_kl            | 0.007900947 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0523      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0358     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00807     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.587        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 18           |
# |    time_elapsed         | 4051         |
# |    total_timesteps      | 45000        |
# | train/                  |              |
# |    approx_kl            | 0.0072515425 |
# |    clip_fraction        | 0.378        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0562       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0349      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00749      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.588      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 19         |
# |    time_elapsed         | 4274       |
# |    total_timesteps      | 47500      |
# | train/                  |            |
# |    approx_kl            | 0.00839086 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.763      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0524     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0365    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00736    |
# ----------------------------------------
# Eval num_timesteps=50000, episode_reward=0.63 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.629        |
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.587        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 20           |
# |    time_elapsed         | 4524         |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0076297945 |
# |    clip_fraction        | 0.4          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0537       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.037       |
# |    std                  | 0.055        |
# |    value_loss           | 0.00736      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.587       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 21          |
# |    time_elapsed         | 4745        |
# |    total_timesteps      | 52500       |
# | train/                  |             |
# |    approx_kl            | 0.008205241 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0528      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00695     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.589       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 22          |
# |    time_elapsed         | 4969        |
# |    total_timesteps      | 55000       |
# | train/                  |             |
# |    approx_kl            | 0.008082602 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0459      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.038      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00718     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.589        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 23           |
# |    time_elapsed         | 5196         |
# |    total_timesteps      | 57500        |
# | train/                  |              |
# |    approx_kl            | 0.0081074415 |
# |    clip_fraction        | 0.393        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.8        |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0521       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0363      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00722      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.595      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 24         |
# |    time_elapsed         | 5419       |
# |    total_timesteps      | 60000      |
# | train/                  |            |
# |    approx_kl            | 0.00877809 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.05       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0367    |
# |    std                  | 0.055      |
# |    value_loss           | 0.00671    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.594       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 25          |
# |    time_elapsed         | 5644        |
# |    total_timesteps      | 62500       |
# | train/                  |             |
# |    approx_kl            | 0.008269574 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0483      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0063      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.592       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 26          |
# |    time_elapsed         | 5869        |
# |    total_timesteps      | 65000       |
# | train/                  |             |
# |    approx_kl            | 0.008467022 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0455      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0369     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00606     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.592       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 27          |
# |    time_elapsed         | 6094        |
# |    total_timesteps      | 67500       |
# | train/                  |             |
# |    approx_kl            | 0.006443367 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0514      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0344     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 28          |
# |    time_elapsed         | 6316        |
# |    total_timesteps      | 70000       |
# | train/                  |             |
# |    approx_kl            | 0.007490708 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0541      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00587     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.591       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 29          |
# |    time_elapsed         | 6539        |
# |    total_timesteps      | 72500       |
# | train/                  |             |
# |    approx_kl            | 0.007984639 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.048       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.035      |
# |    std                  | 0.055       |
# |    value_loss           | 0.00613     |
# -----------------------------------------
# Eval num_timesteps=75000, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.642       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.595       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 30          |
# |    time_elapsed         | 6787        |
# |    total_timesteps      | 75000       |
# | train/                  |             |
# |    approx_kl            | 0.008050986 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.049       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0364     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00593     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.596      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 31         |
# |    time_elapsed         | 7011       |
# |    total_timesteps      | 77500      |
# | train/                  |            |
# |    approx_kl            | 0.00699618 |
# |    clip_fraction        | 0.376      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.8      |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0552     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0357    |
# |    std                  | 0.0551     |
# |    value_loss           | 0.00598    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.591        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 32           |
# |    time_elapsed         | 7239         |
# |    total_timesteps      | 80000        |
# | train/                  |              |
# |    approx_kl            | 0.0073856083 |
# |    clip_fraction        | 0.368        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.042        |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.035       |
# |    std                  | 0.0551       |
# |    value_loss           | 0.0058       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.591       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 33          |
# |    time_elapsed         | 7462        |
# |    total_timesteps      | 82500       |
# | train/                  |             |
# |    approx_kl            | 0.007838533 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0535      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0357     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00552     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 34          |
# |    time_elapsed         | 7684        |
# |    total_timesteps      | 85000       |
# | train/                  |             |
# |    approx_kl            | 0.008654645 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0477      |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0355     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00553     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.596      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 35         |
# |    time_elapsed         | 7906       |
# |    total_timesteps      | 87500      |
# | train/                  |            |
# |    approx_kl            | 0.00857965 |
# |    clip_fraction        | 0.402      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.7      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0507     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0371    |
# |    std                  | 0.0551     |
# |    value_loss           | 0.00542    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.598        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 36           |
# |    time_elapsed         | 8130         |
# |    total_timesteps      | 90000        |
# | train/                  |              |
# |    approx_kl            | 0.0075047566 |
# |    clip_fraction        | 0.377        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0504       |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.0355      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00504      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.598       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 37          |
# |    time_elapsed         | 8354        |
# |    total_timesteps      | 92500       |
# | train/                  |             |
# |    approx_kl            | 0.007746609 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.049       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00533     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.596        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 38           |
# |    time_elapsed         | 8576         |
# |    total_timesteps      | 95000        |
# | train/                  |              |
# |    approx_kl            | 0.0072855866 |
# |    clip_fraction        | 0.379        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0514       |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.0359      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00491      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.601        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 39           |
# |    time_elapsed         | 8801         |
# |    total_timesteps      | 97500        |
# | train/                  |              |
# |    approx_kl            | 0.0064669074 |
# |    clip_fraction        | 0.371        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.053        |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.0346      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00526      |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.652       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 40          |
# |    time_elapsed         | 9045        |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.008375803 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0527      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0367     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00478     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.604       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 41          |
# |    time_elapsed         | 9270        |
# |    total_timesteps      | 102500      |
# | train/                  |             |
# |    approx_kl            | 0.008221001 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0457      |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.0047      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.601        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 42           |
# |    time_elapsed         | 9493         |
# |    total_timesteps      | 105000       |
# | train/                  |              |
# |    approx_kl            | 0.0079430565 |
# |    clip_fraction        | 0.393        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0475       |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0372      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00481      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.602      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 43         |
# |    time_elapsed         | 9716       |
# |    total_timesteps      | 107500     |
# | train/                  |            |
# |    approx_kl            | 0.00746839 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -94.7      |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 0.0481     |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.038     |
# |    std                  | 0.0551     |
# |    value_loss           | 0.00464    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.599       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 44          |
# |    time_elapsed         | 9937        |
# |    total_timesteps      | 110000      |
# | train/                  |             |
# |    approx_kl            | 0.008502282 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0454      |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0366     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00481     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.603       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 45          |
# |    time_elapsed         | 10162       |
# |    total_timesteps      | 112500      |
# | train/                  |             |
# |    approx_kl            | 0.008866976 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0456      |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00486     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 46          |
# |    time_elapsed         | 10387       |
# |    total_timesteps      | 115000      |
# | train/                  |             |
# |    approx_kl            | 0.008300274 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0447      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00456     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.603        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 47           |
# |    time_elapsed         | 10611        |
# |    total_timesteps      | 117500       |
# | train/                  |              |
# |    approx_kl            | 0.0076956516 |
# |    clip_fraction        | 0.387        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -94.7        |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0425       |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0369      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00444      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.605       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 48          |
# |    time_elapsed         | 10832       |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.007781484 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0501      |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00432     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.606       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 49          |
# |    time_elapsed         | 11059       |
# |    total_timesteps      | 122500      |
# | train/                  |             |
# |    approx_kl            | 0.008580573 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0497      |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0348     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00475     |
# -----------------------------------------
# Eval num_timesteps=125000, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.654       |
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.602       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 50          |
# |    time_elapsed         | 11304       |
# |    total_timesteps      | 125000      |
# | train/                  |             |
# |    approx_kl            | 0.008682127 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -94.7       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0438      |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00468     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    entropy_loss         | -95         |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0485      |
# |    n_updates            | 5920        |
# |    policy_gradient_loss | -0.0346     |
# |    std                  | 0.0549      |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.661       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 298         |
# |    time_elapsed         | 67162       |
# |    total_timesteps      | 745000      |
# | train/                  |             |
# |    approx_kl            | 0.008430331 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -95         |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0447      |
# |    n_updates            | 5940        |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.0549      |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.658       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 299         |
# |    time_elapsed         | 67385       |
# |    total_timesteps      | 747500      |
# | train/                  |             |
# |    approx_kl            | 0.006966761 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -95         |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.053       |
# |    n_updates            | 5960        |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.0549      |
# |    value_loss           | 0.00285     |
# -----------------------------------------
# Eval num_timesteps=750000, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.662        |
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.659        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 300          |
# |    time_elapsed         | 67631        |
# |    total_timesteps      | 750000       |
# | train/                  |              |
# |    approx_kl            | 0.0077453847 |
# |    clip_fraction        | 0.394        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -95          |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0562       |
# |    n_updates            | 5980         |
# |    policy_gradient_loss | -0.0351      |
# |    std                  | 0.0549       |
# |    value_loss           | 0.003        |
# ------------------------------------------
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
# /data/ad181/RemoteDir/multilevel_ppo/stable_baselines_mlppo/stable_baselines3/common/envs/multi_level_model/level_mapping_functions.py:43: NumbaExperimentalFeatureWarning: First-class function type feature is experimental
#   for j in range(len(p_1)-1):
